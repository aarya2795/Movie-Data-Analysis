# %% [markdown]
# # TMDB Movie Data Analysis and Visualization
#
# What can we say about the success of a movie before it is released? <br>
# Are there certain companies (Pixar?) that have found a consistent formula? <br>
# Given that major films costing over $100 million to produce can still flop,
# this question is more important than ever to the industry. Film aficionados might have different interests. <br>
# Can we predict which films will be highly rated, whether or not they are a commercial success?

# %%
# Importing the required packages here
import numpy as np
import pandas as pd
import seaborn as sns
import ast, json

from datetime import datetime
import matplotlib.pyplot as plt

# %%
# Let's load the dataset and create their dataframes
credits_df = pd.read_csv('tmdb_5000_credits.csv')
movies_df = pd.read_csv('tmdb_5000_movies.csv')

# %% [markdown]
# # Looking at this dataset, we need to define a set of questions.
#
# Defining the primary questions here:
# 1. Which are the 5 most expensive movies? Comparison between the extremes.
# 2. Top 5 most profitable movies? Comparison between the min and max profits.
# 3. Most talked about Movies?
# 4. Average runtime of movies?
# 5. Movies which are rated above 7 by the critics?
# 6. Which year did we have the most profitable movies?
#
# Then there will be a set of seconday questions related to the questions above
# 1. Most successful genre.
# 2. Frequent Cast in movies.
# 3. Average budget of the profitable movies.
# 4. Average duration of the most profitable movies.
# 5. Language of the most profitable movies."""

# %%
# merging the two files
movies_df = pd.merge(movies_df,credits_df,left_on='id',right_on='movie_id', how='left', suffixes=('', '_y'))
movies_df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'movie_id', 'title_y', 'cast', 'crew'],
#       dtype='object')

# %% [markdown]
# Data Cleaning Process
# After observing the dataset and proposed questions for the analysis,<br> we will be keeping only relevent data deleting the unsued data so that we can make our calculation easy and understandable.
#
# Steps to be taken to clean the data:-
#
# <ul style="list-style-type:disc;">
# <li>We need to remove unused column such as id, imdb_id, vote_count, production_company, keywords, homepage etc.</li>
# <li>Removing the duplicacy in the rows(if any).</li>
# <li>Some movies in the database have zero budget or zero revenue, that is there value has not been recorded so we will be discarding such entries.</li>
# <li>Changing release date column into date format.</li>
#  <li>Replacing zero with NAN in runtime column.</li>
# <li>Changing format of budget and revenue column.</li>
# </ul>

# %%
# First step is to clean the data and see which are the redundant or unnecessary cols
del_col_list = ['keywords', 'homepage', 'status', 'tagline', 'original_language', 'homepage', 
                'overview', 'production_companies', 'original_title', 'title_y']

movies_df = movies_df.drop(del_col_list, axis=1)

# %% [markdown]
# How to handle the Json in Dataset?
# The main problem with this dataset is the .json format. <br>Many columns in the dataset are in json format,
# therefore cleaning the dataset was the main challenge. <br>For people who don't know about JSON(JavaScript Object Notation),
# it is basically a syntax for storing and exchanging data between two computers. It is mainly in a key:value format,
# and is embedded into a string.

# %%
# we see that there are columns which are in json format,
# let's flatten these json data into easyily interpretable lists
def parse_col_json(column, key):
    """
    Args:
        column: string
            name of the column to be processed.
        key: string
            name of the dictionary key which needs to be extracted
    """
    for index,i in zip(movies_df.index,movies_df[column].apply(json.loads)):
        list1=[]
        for j in range(len(i)):
            list1.append((i[j][key]))# the key 'name' contains the name of the genre
        movies_df.loc[index,column]=str(list1)
    
parse_col_json('genres', 'name')
parse_col_json('spoken_languages', 'name')
parse_col_json('cast', 'name')
parse_col_json('production_countries', 'name')

# %%
movies_df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  ['Action', 'Adventure', 'Fantasy', 'Science Fi...   19995
# 1  300000000                 ['Adventure', 'Fantasy', 'Action']     285
# 2  245000000                   ['Action', 'Adventure', 'Crime']  206647
# 3  250000000           ['Action', 'Crime', 'Drama', 'Thriller']   49026
# 4  260000000         ['Action', 'Adventure', 'Science Fiction']   49529
#
#    popularity                            production_countries release_date  \
# 0  150.437577  ['United States of America', 'United Kingdom']   2009-12-10
# 1  139.082615                    ['United States of America']   2007-05-19
# 2  107.376788  ['United Kingdom', 'United States of America']   2015-10-26
# 3  112.312950                    ['United States of America']   2012-07-16
# 4   43.926995                    ['United States of America']   2012-03-07
#
#       revenue  runtime                                   spoken_languages  \
# 0  2787965087    162.0                             ['English', 'Español']
# 1   961000000    169.0                                        ['English']
# 2   880674609    148.0  ['Français', 'English', 'Español', 'Italiano',...
# 3  1084939099    165.0                                        ['English']
# 4   284139100    132.0                                        ['English']
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124
#
#    movie_id                                               cast  \
# 0     19995  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 1       285  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 2    206647  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...
# 3     49026  ['Christian Bale', 'Michael Caine', 'Gary Oldm...
# 4     49529  ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
#  dropping the duplicates from the dataset.
print(movies_df.shape)
movies_df = movies_df.drop_duplicates(keep='first')
print(movies_df.shape)
# Out:
# (4803, 15)
# (4803, 15)

# %%
# replacing all the zeros from revenue and budget cols.
cols = ['budget', 'revenue']
movies_df[cols] = movies_df[cols].replace(0, np.nan)

# %%
# dropping all the rows with na in the columns mentioned above in the list.
movies_df.dropna(subset=cols, inplace=True)
movies_df.shape
# Out:
# (3229, 15)

# %%
movies_df.release_date = pd.to_datetime(movies_df['release_date'])

# %%
movies_df['release_year'] = movies_df['release_date'].dt.year

# %%
change_cols=['budget', 'revenue']
#changing data type
movies_df[change_cols]=movies_df[change_cols].applymap(np.int64)
movies_df.dtypes
# Out:
# budget                           int64
# genres                          object
# id                               int64
# popularity                     float64
# production_countries            object
# release_date            datetime64[ns]
# revenue                          int64
# runtime                        float64
# spoken_languages                object
# title                           object
# vote_average                   float64
# vote_count                       int64
# movie_id                         int64
# cast                            object
# crew                            object
# release_year                     int64
# dtype: object

# %%
# Answer to question #1.
# To find out the most expensive movies, we need to look at the budget set for them which is an indicator of expense.

expensive_movies_df = movies_df.sort_values(by ='budget', ascending=False).head()
expensive_movies_df

# below are the 5 most expensive movies in descending order.
# Out:
#        budget                                             genres     id  \
# 17  380000000                 ['Adventure', 'Action', 'Fantasy']   1865
# 1   300000000                 ['Adventure', 'Fantasy', 'Action']    285
# 7   280000000         ['Action', 'Adventure', 'Science Fiction']  99861
# 10  270000000  ['Adventure', 'Fantasy', 'Action', 'Science Fi...   1452
# 4   260000000         ['Action', 'Adventure', 'Science Fiction']  49529
#
#     popularity          production_countries release_date     revenue  \
# 17  135.413856  ['United States of America']   2011-05-14  1045713802
# 1   139.082615  ['United States of America']   2007-05-19   961000000
# 7   134.279229  ['United States of America']   2015-04-22  1405403694
# 10   57.925623  ['United States of America']   2006-06-28   391081192
# 4    43.926995  ['United States of America']   2012-03-07   284139100
#
#     runtime                    spoken_languages  \
# 17    136.0              ['English', 'Español']
# 1     169.0                         ['English']
# 7     141.0                         ['English']
# 10    154.0  ['English', 'Français', 'Deutsch']
# 4     132.0                         ['English']
#
#                                           title  vote_average  vote_count  \
# 17  Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 1      Pirates of the Caribbean: At World's End           6.9        4500
# 7                       Avengers: Age of Ultron           7.3        6767
# 10                             Superman Returns           5.4        1400
# 4                                   John Carter           6.1        2124
#
#     movie_id                                               cast  \
# 17      1865  ['Johnny Depp', 'Penélope Cruz', 'Ian McShane'...
# 1        285  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 7      99861  ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark...
# 10      1452  ['Brandon Routh', 'Kevin Spacey', 'Kate Boswor...
# 4      49529  ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...
#
#                                                  crew  release_year
# 17  [{"credit_id": "566b4f54c3a3683f56005151", "de...          2011
# 1   [{"credit_id": "52fe4232c3a36847f800b579", "de...          2007
# 7   [{"credit_id": "55d5f7d4c3a3683e7e0016eb", "de...          2015
# 10  [{"credit_id": "553bef6a9251416874003c8f", "de...          2006
# 4   [{"credit_id": "52fe479ac3a36847f813eaa3", "de...          2012

# %%
expensive_movies_df = movies_df.sort_values(by = 'budget', ascending=False).head()
expensive_movies_df
# Out:
#        budget                                             genres     id  \
# 17  380000000                 ['Adventure', 'Action', 'Fantasy']   1865
# 1   300000000                 ['Adventure', 'Fantasy', 'Action']    285
# 7   280000000         ['Action', 'Adventure', 'Science Fiction']  99861
# 10  270000000  ['Adventure', 'Fantasy', 'Action', 'Science Fi...   1452
# 4   260000000         ['Action', 'Adventure', 'Science Fiction']  49529
#
#     popularity          production_countries release_date     revenue  \
# 17  135.413856  ['United States of America']   2011-05-14  1045713802
# 1   139.082615  ['United States of America']   2007-05-19   961000000
# 7   134.279229  ['United States of America']   2015-04-22  1405403694
# 10   57.925623  ['United States of America']   2006-06-28   391081192
# 4    43.926995  ['United States of America']   2012-03-07   284139100
#
#     runtime                    spoken_languages  \
# 17    136.0              ['English', 'Español']
# 1     169.0                         ['English']
# 7     141.0                         ['English']
# 10    154.0  ['English', 'Français', 'Deutsch']
# 4     132.0                         ['English']
#
#                                           title  vote_average  vote_count  \
# 17  Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 1      Pirates of the Caribbean: At World's End           6.9        4500
# 7                       Avengers: Age of Ultron           7.3        6767
# 10                             Superman Returns           5.4        1400
# 4                                   John Carter           6.1        2124
#
#     movie_id                                               cast  \
# 17      1865  ['Johnny Depp', 'Penélope Cruz', 'Ian McShane'...
# 1        285  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...
# 7      99861  ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark...
# 10      1452  ['Brandon Routh', 'Kevin Spacey', 'Kate Boswor...
# 4      49529  ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...
#
#                                                  crew  release_year
# 17  [{"credit_id": "566b4f54c3a3683f56005151", "de...          2011
# 1   [{"credit_id": "52fe4232c3a36847f800b579", "de...          2007
# 7   [{"credit_id": "55d5f7d4c3a3683e7e0016eb", "de...          2015
# 10  [{"credit_id": "553bef6a9251416874003c8f", "de...          2006
# 4   [{"credit_id": "52fe479ac3a36847f813eaa3", "de...          2012

# %%
"""Since we need to compare the minimums and maximums in 3 questions, we can write a generi function to do that for us. 
It will remove all the redundancy in code for such questions."""
def find_min_max_in(col):
    """
    The function takes in a column and returns the top 5
    and bottom 5 movies dataframe in that column.
    
    args:
        col: string - column name
    return:
        info_df: dataframe - final 5 movies dataframe
    """
    
    top = movies_df[col].idxmax()
    top_df = pd.DataFrame(movies_df.loc[top])
    
    bottom = movies_df[col].idxmin()
    bottom_df = pd.DataFrame(movies_df.loc[bottom])
    
    info_df = pd.concat([top_df, bottom_df], axis=1)
    return info_df

find_min_max_in('budget')
# Out:
#                                                                    17    \
# budget                                                        380000000
# genres                               ['Adventure', 'Action', 'Fantasy']
# id                                                                 1865
# popularity                                                      135.414
# production_countries                       ['United States of America']
# release_date                                        2011-05-14 00:00:00
# revenue                                                      1045713802
# runtime                                                             136
# spoken_languages                                 ['English', 'Español']
# title                       Pirates of the Caribbean: On Stranger Tides
# vote_average                                                        6.4
# vote_count                                                         4948
# movie_id                                                           1865
# cast                  ['Johnny Depp', 'Penélope Cruz', 'Ian McShane'...
# crew                  [{"credit_id": "566b4f54c3a3683f56005151", "de...
# release_year                                                       2011
#
#                                                                    4238
# budget                                                                1
# genres                                              ['Drama', 'Comedy']
# id                                                                 3082
# popularity                                                      28.2765
# production_countries                       ['United States of America']
# release_date                                        1936-02-05 00:00:00
# revenue                                                         8500000
# runtime                                                              87
# spoken_languages                                            ['English']
# title                                                      Modern Times
# vote_average                                                        8.1
# vote_count                                                          856
# movie_id                                                           3082
# cast                  ['Charlie Chaplin', 'Paulette Goddard', 'Henry...
# crew                  [{"credit_id": "5621aeadc3a3680e1d00a09a", "de...
# release_year                                                       1936

# %%
#ans to Q2
# to find the most profitable movies, we need to find who made the most 
# amount after deducting the budget from the revenue generated.
movies_df['profit'] = movies_df['revenue'] - movies_df['budget']
cols = ['budget',
         'profit',
         'revenue',
         'genres',
         'id',
         'popularity',
         'production_countries',
        'release_date',
        'release_year',
         'runtime',
         'spoken_languages',
         'title',
        'cast',
         'vote_average',
         'vote_count']
movies_df = movies_df[cols]
movies_df.sort_values(by = ['profit'], ascending=False).head()
# Out:
#        budget      profit     revenue  \
# 0   237000000  2550965087  2787965087
# 25  200000000  1645034188  1845034188
# 28  150000000  1363528810  1513528810
# 44  190000000  1316249360  1506249360
# 16  220000000  1299557910  1519557910
#
#                                                genres      id  popularity  \
# 0   ['Action', 'Adventure', 'Fantasy', 'Science Fi...   19995  150.437577
# 25                   ['Drama', 'Romance', 'Thriller']     597  100.025899
# 28  ['Action', 'Adventure', 'Science Fiction', 'Th...  135397  418.708552
# 44                                         ['Action']  168259  102.322217
# 16         ['Science Fiction', 'Action', 'Adventure']   24428  144.448633
#
#                               production_countries release_date  release_year  \
# 0   ['United States of America', 'United Kingdom']   2009-12-10          2009
# 25                    ['United States of America']   1997-11-18          1997
# 28                    ['United States of America']   2015-06-09          2015
# 44           ['Japan', 'United States of America']   2015-04-01          2015
# 16                    ['United States of America']   2012-04-25          2012
#
#     runtime                                   spoken_languages  \
# 0     162.0                             ['English', 'Español']
# 25    194.0  ['English', 'Français', 'Deutsch', 'svenska', ...
# 28    124.0                                        ['English']
# 44    137.0                                        ['English']
# 16    143.0                                        ['English']
#
#              title                                               cast  \
# 0           Avatar  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 25         Titanic  ['Kate Winslet', 'Leonardo DiCaprio', 'Frances...
# 28  Jurassic World  ['Chris Pratt', 'Bryce Dallas Howard', 'Irrfan...
# 44       Furious 7  ['Vin Diesel', 'Paul Walker', 'Dwayne Johnson'...
# 16    The Avengers  ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruf...
#
#     vote_average  vote_count
# 0            7.2       11800
# 25           7.5        7562
# 28           6.5        8662
# 44           7.3        4176
# 16           7.4       11776

# %%
# Comparison between min and max profits
find_min_max_in('profit')
# Out:
#                                                                      0   \
# budget                                                        237000000
# profit                                                       2550965087
# revenue                                                      2787965087
# genres                ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# id                                                                19995
# popularity                                                      150.438
# production_countries     ['United States of America', 'United Kingdom']
# release_date                                        2009-12-10 00:00:00
# release_year                                                       2009
# runtime                                                             162
# spoken_languages                                 ['English', 'Español']
# title                                                            Avatar
# cast                  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# vote_average                                                        7.2
# vote_count                                                        11800
#
#                                                                      13
# budget                                                        255000000
# profit                                                       -165710090
# revenue                                                        89289910
# genres                               ['Action', 'Adventure', 'Western']
# id                                                                57201
# popularity                                                       49.047
# production_countries                       ['United States of America']
# release_date                                        2013-07-03 00:00:00
# release_year                                                       2013
# runtime                                                             149
# spoken_languages                                            ['English']
# title                                                   The Lone Ranger
# cast                  ['Johnny Depp', 'Armie Hammer', 'William Ficht...
# vote_average                                                        5.9
# vote_count                                                         2311

# %%
# to find the most talked about movies, we can sort the dataframe on the popularity column
popular_movies_df = movies_df.sort_values(by ='budget', ascending=False).head()
popular_movies_df.head()
# Out:
#        budget      profit     revenue  \
# 17  380000000   665713802  1045713802
# 1   300000000   661000000   961000000
# 7   280000000  1125403694  1405403694
# 10  270000000   121081192   391081192
# 4   260000000    24139100   284139100
#
#                                                genres     id  popularity  \
# 17                 ['Adventure', 'Action', 'Fantasy']   1865  135.413856
# 1                  ['Adventure', 'Fantasy', 'Action']    285  139.082615
# 7          ['Action', 'Adventure', 'Science Fiction']  99861  134.279229
# 10  ['Adventure', 'Fantasy', 'Action', 'Science Fi...   1452   57.925623
# 4          ['Action', 'Adventure', 'Science Fiction']  49529   43.926995
#
#             production_countries release_date  release_year  runtime  \
# 17  ['United States of America']   2011-05-14          2011    136.0
# 1   ['United States of America']   2007-05-19          2007    169.0
# 7   ['United States of America']   2015-04-22          2015    141.0
# 10  ['United States of America']   2006-06-28          2006    154.0
# 4   ['United States of America']   2012-03-07          2012    132.0
#
#                       spoken_languages  \
# 17              ['English', 'Español']
# 1                          ['English']
# 7                          ['English']
# 10  ['English', 'Français', 'Deutsch']
# 4                          ['English']
#
#                                           title  \
# 17  Pirates of the Caribbean: On Stranger Tides
# 1      Pirates of the Caribbean: At World's End
# 7                       Avengers: Age of Ultron
# 10                             Superman Returns
# 4                                   John Carter
#
#                                                  cast  vote_average  \
# 17  ['Johnny Depp', 'Penélope Cruz', 'Ian McShane'...           6.4
# 1   ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...           6.9
# 7   ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark...           7.3
# 10  ['Brandon Routh', 'Kevin Spacey', 'Kate Boswor...           5.4
# 4   ['Taylor Kitsch', 'Lynn Collins', 'Samantha Mo...           6.1
#
#     vote_count
# 17        4948
# 1         4500
# 7         6767
# 10        1400
# 4         2124

# %%
# in terms of popularity score
find_min_max_in('popularity')
# Out:
#                                                                    546   \
# budget                                                         74000000
# profit                                                       1082730962
# revenue                                                      1156730962
# genres                   ['Family', 'Animation', 'Adventure', 'Comedy']
# id                                                               211672
# popularity                                                      875.581
# production_countries                       ['United States of America']
# release_date                                        2015-06-17 00:00:00
# release_year                                                       2015
# runtime                                                              91
# spoken_languages                                            ['English']
# title                                                           Minions
# cast                  ['Sandra Bullock', 'Jon Hamm', 'Michael Keaton...
# vote_average                                                        6.4
# vote_count                                                         4571
#
#                                                                    3921
# budget                                                          3000000
# profit                                                          3804016
# revenue                                                         6804016
# genres                                                        ['Drama']
# id                                                                44634
# popularity                                                     0.019984
# production_countries                       ['United States of America']
# release_date                                        2004-09-30 00:00:00
# release_year                                                       2004
# runtime                                                              94
# spoken_languages                                            ['English']
# title                                             Woman Thou Art Loosed
# cast                  ['Kimberly Elise', 'Loretta Devine', 'Debbi Mo...
# vote_average                                                          5
# vote_count                                                            3

# %%
# ans to Q3
# in terms of runtime
find_min_max_in('runtime')
# Out:
#                                                                    2384  \
# budget                                                         18000000
# profit                                                        -17128721
# revenue                                                          871279
# genres                        ['Crime', 'Drama', 'Thriller', 'History']
# id                                                                43434
# popularity                                                      1.13838
# production_countries                              ['France', 'Germany']
# release_date                                        2010-05-19 00:00:00
# release_year                                                       2010
# runtime                                                             338
# spoken_languages      ['Français', 'Deutsch', 'English', 'Español', ...
# title                                                            Carlos
# cast                  ['Edgar Ramírez', 'Alexander Scheer', 'Fadi Ab...
# vote_average                                                        6.7
# vote_count                                                           50
#
#                                                                    3626
# budget                                                          5000000
# profit                                                          -925977
# revenue                                                         4074023
# genres                                                  ['Documentary']
# id                                                                78394
# popularity                                                      4.49837
# production_countries                       ['France', 'United Kingdom']
# release_date                                        2010-05-14 00:00:00
# release_year                                                       2010
# runtime                                                              41
# spoken_languages                                            ['English']
# title                        Sea Rex 3D: Journey to a Prehistoric World
# cast                  ['Guillaume Denaiffe', 'Norbert Ferrer', 'Chlo...
# vote_average                                                        5.9
# vote_count                                                           11

# %%
# Average runtime of movies 
movies_df['runtime'].mean()
# Out:
# 110.72437287085785

# %%
# ans to Q4
# movies rated above 7 
movies_df[movies_df['vote_average'] >= 7.0]
# Out:
#          budget      profit     revenue  \
# 0     237000000  2550965087  2787965087
# 3     250000000   834939099  1084939099
# 6     260000000   331794936   591794936
# 7     280000000  1125403694  1405403694
# 8     250000000   683959197   933959197
# 12    200000000   865659812  1065659812
# 16    220000000  1299557910  1519557910
# 19    250000000   706019788   956019788
# 22    250000000   708400000   958400000
# 25    200000000  1645034188  1845034188
# 26    250000000   903304495  1153304495
# 34    200000000   543559607   743559607
# 42    200000000   866969703  1066969703
# 44    190000000  1316249360  1506249360
# 46    250000000   497862775   747862775
# 47    190000000   277365246   467365246
# 49    105000000   246040419   351040419
# 57    180000000   341311860   521311860
# 65    185000000   819558444  1004558444
# 66    175000000   560099082   735099082
# 68    140000000   445174222   585174222
# 69    170000000    15770160   185770160
# 74    178000000   192541256   370541256
# 77    175000000   682611174   857611174
# 81    180000000   578539785   758539785
# 82    170000000   540644566   710644566
# 85    170000000   544766572   714766572
# 88    165000000   487105443   652105443
# 89    165000000   306222889   471222889
# 92    165000000   329878759   494878759
# ...         ...         ...         ...
# 4456     800000     2016116     2816116
# 4461     800000     -737148       62852
# 4479     730000     7270000     8000000
# 4480     700000     7130611     7830611
# 4495     609000     2593000     3202000
# 4497     600000    33905110    34505110
# 4507     560000    11739668    12299668
# 4511     500000    32956317    33456317
# 4518     500000     8179814     8679814
# 4521    2053648    -1553648      500000
# 4524     500000      345188      845188
# 4535    2000000    -1728159      271841
# 4579     400000     4628948     5028948
# 4582        218     1161796     1162014
# 4592     385907     8008844     8394751
# 4595     350000    29050000    29400000
# 4602     350000      650000     1000000
# 4604     325000     4175000     4500000
# 4606     300000     7508524     7808524
# 4641        250         -47         203
# 4661     245000    21755000    22000000
# 4672     200000    14300000    14500000
# 4695     180000      720000      900000
# 4696       8000      461947      469947
# 4704     160000    20550513    20710513
# 4713     160000     6546368     6706368
# 4724      10000     6990000     7000000
# 4738      60000     3161152     3221152
# 4773      27000     3124130     3151130
# 4792      20000       79000       99000
#
#                                                  genres      id  popularity  \
# 0     ['Action', 'Adventure', 'Fantasy', 'Science Fi...   19995  150.437577
# 3              ['Action', 'Crime', 'Drama', 'Thriller']   49026  112.312950
# 6                               ['Animation', 'Family']   38757   48.681969
# 7            ['Action', 'Adventure', 'Science Fiction']   99861  134.279229
# 8                    ['Adventure', 'Fantasy', 'Family']     767   98.885637
# 12                   ['Adventure', 'Fantasy', 'Action']      58  145.847379
# 16           ['Science Fiction', 'Action', 'Adventure']   24428  144.448633
# 19                   ['Action', 'Adventure', 'Fantasy']  122917  120.965743
# 22                             ['Adventure', 'Fantasy']   57158   94.370564
# 25                     ['Drama', 'Romance', 'Thriller']     597  100.025899
# 26           ['Adventure', 'Action', 'Science Fiction']  271110  198.372395
# 34                              ['Animation', 'Family']   62211   89.186492
# 42                    ['Animation', 'Family', 'Comedy']   10193   59.995418
# 44                                           ['Action']  168259  102.322217
# 46    ['Action', 'Adventure', 'Fantasy', 'Science Fi...  127585  118.078691
# 47           ['Action', 'Adventure', 'Science Fiction']   54138   78.291018
# 49                                 ['Drama', 'Romance']   64682   61.196071
# 57                              ['Animation', 'Family']   10681   66.390712
# 65             ['Drama', 'Action', 'Crime', 'Thriller']     155  187.322927
# 66       ['Animation', 'Comedy', 'Family', 'Adventure']   14160   92.201962
# 68           ['Action', 'Science Fiction', 'Adventure']    1726  120.725053
# 69                     ['Adventure', 'Drama', 'Family']   44826   32.319043
# 74                        ['Action', 'Science Fiction']  137113   79.456485
# 77           ['Drama', 'Comedy', 'Animation', 'Family']  150540  128.655964
# 81    ['Fantasy', 'Adventure', 'Action', 'Family', '...  102651  110.620647
# 82    ['Science Fiction', 'Action', 'Drama', 'Thrill...  119450  243.791743
# 85           ['Action', 'Adventure', 'Science Fiction']  100402   72.225265
# 88    ['Adventure', 'Family', 'Animation', 'Action',...  177572  203.734590
# 89       ['Family', 'Animation', 'Comedy', 'Adventure']   82690   62.341073
# 92      ['Fantasy', 'Adventure', 'Animation', 'Family']   10191   67.263269
# ...                                                 ...     ...         ...
# 4456                               ['Drama', 'Romance']   25461    3.643662
# 4461                                          ['Drama']   26899    5.292536
# 4479                                        ['Western']     288   18.644023
# 4480                                    ['Documentary']   14275    9.188431
# 4495                     ['Comedy', 'Music', 'Romance']    3080    3.898498
# 4497                ['History', 'Documentary', 'Music']    9459    3.409764
# 4507                                ['Comedy', 'Music']     704   10.730056
# 4511                                          ['Drama']   14438    6.093989
# 4518                                ['Drama', 'Comedy']    2056   11.578545
# 4521                                    ['Documentary']   14271    2.778633
# 4524                                    ['Documentary']   84401    0.109579
# 4535                                ['Action', 'Drama']     346   39.756748
# 4579                 ['Adventure', 'Comedy', 'Fantasy']     762   64.782984
# 4582                           ['Documentary', 'Drama']    1435    1.063439
# 4592                                          ['Drama']    3059    3.232447
# 4595                                         ['Horror']     764   35.037625
# 4602                                          ['Drama']     389   59.259204
# 4604                              ['Comedy', 'Romance']    3078   11.871424
# 4606                           ['Music', 'Documentary']   21525    1.314576
# 4641                   ['Drama', 'Comedy', 'Animation']   51942    0.293649
# 4661                        ['Drama', 'Romance', 'War']    3060    0.785744
# 4672                                        ['Western']     391   38.771062
# 4695                      ['Drama', 'Comedy', 'Family']   21334    7.072118
# 4696                               ['Drama', 'Romance']   79120    1.041254
# 4704                      ['Drama', 'Music', 'Romance']    5723   19.052179
# 4713                         ['Documentary', 'History']    1779    3.284903
# 4724  ['Drama', 'Fantasy', 'Horror', 'Science Fiction']     985   20.399578
# 4738                   ['Mystery', 'Drama', 'Thriller']     473   27.788067
# 4773                                         ['Comedy']    2292   19.748658
# 4792         ['Crime', 'Horror', 'Mystery', 'Thriller']   36095    0.212443
#
#                                    production_countries release_date  \
# 0        ['United States of America', 'United Kingdom']   2009-12-10
# 3                          ['United States of America']   2012-07-16
# 6                          ['United States of America']   2010-11-24
# 7                          ['United States of America']   2015-04-22
# 8        ['United Kingdom', 'United States of America']   2009-07-07
# 12    ['Jamaica', 'United States of America', 'Baham...   2006-06-20
# 16                         ['United States of America']   2012-04-25
# 19          ['New Zealand', 'United States of America']   2014-12-10
# 22          ['New Zealand', 'United States of America']   2013-12-11
# 25                         ['United States of America']   1997-11-18
# 26                         ['United States of America']   2016-04-27
# 34                         ['United States of America']   2013-06-20
# 42                         ['United States of America']   2010-06-16
# 44                ['Japan', 'United States of America']   2015-04-01
# 46       ['United Kingdom', 'United States of America']   2014-05-15
# 47                         ['United States of America']   2013-05-05
# 49            ['United States of America', 'Australia']   2013-05-10
# 57                         ['United States of America']   2008-06-22
# 65       ['United Kingdom', 'United States of America']   2008-07-16
# 66                         ['United States of America']   2009-05-13
# 68                         ['United States of America']   2008-04-30
# 69    ['France', 'United States of America', 'United...   2011-11-22
# 74            ['Australia', 'United States of America']   2014-05-27
# 77                         ['United States of America']   2015-06-09
# 81                         ['United States of America']   2014-05-28
# 82                         ['United States of America']   2014-06-26
# 85                         ['United States of America']   2014-03-20
# 88                         ['United States of America']   2014-10-24
# 89                         ['United States of America']   2012-11-01
# 92                         ['United States of America']   2010-03-05
# ...                                                 ...          ...
# 4456                       ['United States of America']   2002-05-16
# 4461                       ['United States of America']   2003-01-17
# 4479                       ['United States of America']   1952-03-27
# 4480                       ['United States of America']   1994-09-12
# 4495                       ['United States of America']   1935-09-06
# 4497                       ['United States of America']   1970-03-26
# 4507                                 ['United Kingdom']   1964-07-06
# 4511                       ['United States of America']   2008-09-26
# 4518                       ['United States of America']   2003-01-26
# 4521                       ['United States of America']   1999-10-22
# 4524                                                 []   2012-02-24
# 4535                                          ['Japan']   1954-04-26
# 4579                                 ['United Kingdom']   1975-03-13
# 4582                       ['United States of America']   2003-10-19
# 4592                       ['United States of America']   1916-09-04
# 4595                       ['United States of America']   1981-10-15
# 4602                       ['United States of America']   1957-03-25
# 4604                       ['United States of America']   1934-02-22
# 4606                       ['United States of America']   2003-01-23
# 4641                       ['United States of America']   1998-08-28
# 4661                       ['United States of America']   1925-11-05
# 4672                      ['Italy', 'Germany', 'Spain']   1964-09-12
# 4695                                           ['Iran']   1997-08-01
# 4696                                 ['United Kingdom']   2011-09-22
# 4704                                        ['Ireland']   2007-03-23
# 4713                       ['United States of America']   1989-09-01
# 4724                       ['United States of America']   1977-03-19
# 4738                       ['United States of America']   1998-07-10
# 4773                       ['United States of America']   1994-09-13
# 4792                                          ['Japan']   1997-11-06
#
#       release_year  runtime  \
# 0             2009    162.0
# 3             2012    165.0
# 6             2010    100.0
# 7             2015    141.0
# 8             2009    153.0
# 12            2006    151.0
# 16            2012    143.0
# 19            2014    144.0
# 22            2013    161.0
# 25            1997    194.0
# 26            2016    147.0
# 34            2013    104.0
# 42            2010    103.0
# 44            2015    137.0
# 46            2014    131.0
# 47            2013    132.0
# 49            2013    143.0
# 57            2008     98.0
# 65            2008    152.0
# 66            2009     96.0
# 68            2008    126.0
# 69            2011    126.0
# 74            2014    113.0
# 77            2015     94.0
# 81            2014     97.0
# 82            2014    130.0
# 85            2014    136.0
# 88            2014    102.0
# 89            2012    108.0
# 92            2010     98.0
# ...            ...      ...
# 4456          2002     88.0
# 4461          2003     94.0
# 4479          1952     85.0
# 4480          1994    171.0
# 4495          1935    101.0
# 4497          1970    225.0
# 4507          1964     88.0
# 4511          2008    122.0
# 4518          2003     88.0
# 4521          1999    102.0
# 4524          2012     93.0
# 4535          1954    207.0
# 4579          1975     91.0
# 4582          2003     91.0
# 4592          1916    197.0
# 4595          1981     85.0
# 4602          1957     96.0
# 4604          1934    105.0
# 4606          2003    112.0
# 4641          1998     72.0
# 4661          1925    151.0
# 4672          1964     99.0
# 4695          1997     89.0
# 4696          2011     96.0
# 4704          2007     85.0
# 4713          1989     91.0
# 4724          1977     89.0
# 4738          1998     84.0
# 4773          1994     92.0
# 4792          1997    111.0
#
#                                        spoken_languages  \
# 0                                ['English', 'Español']
# 3                                           ['English']
# 6                                           ['English']
# 7                                           ['English']
# 8                                           ['English']
# 12             ['English', 'Türkçe', 'ελληνικά', '普通话']
# 16                                          ['English']
# 19                                          ['English']
# 22                                          ['English']
# 25    ['English', 'Français', 'Deutsch', 'svenska', ...
# 26          ['Română', 'English', 'Deutsch', 'Pусский']
# 34                                          ['English']
# 42                               ['English', 'Español']
# 44                                          ['English']
# 46                                          ['English']
# 47                                          ['English']
# 49                                          ['English']
# 57                                          ['English']
# 65                                   ['English', '普通话']
# 66                                          ['English']
# 68              ['English', 'فارسی', 'اردو', 'العربية']
# 69                                          ['English']
# 74                                          ['English']
# 77                                          ['English']
# 81                                          ['English']
# 82                                          ['English']
# 85                                          ['English']
# 88                                          ['English']
# 89                                          ['English']
# 92                                          ['English']
# ...                                                 ...
# 4456                             ['English', 'Español']
# 4461                                        ['English']
# 4479                                        ['English']
# 4480                                        ['English']
# 4495                            ['English', 'Italiano']
# 4497                                        ['English']
# 4507                                        ['English']
# 4511                                        ['English']
# 4518                                        ['English']
# 4521                                        ['English']
# 4524                                                 []
# 4535                                            ['日本語']
# 4579                   ['Français', 'Latin', 'English']
# 4582                                        ['English']
# 4592                                        ['English']
# 4595                                        ['English']
# 4602                                        ['English']
# 4604                                        ['English']
# 4606                                        ['English']
# 4641                                        ['English']
# 4661                                                 []
# 4672                            ['Italiano', 'Español']
# 4695                                          ['فارسی']
# 4696                                        ['English']
# 4704                                        ['English']
# 4713                                        ['English']
# 4724                                        ['English']
# 4738                                        ['English']
# 4773                                        ['English']
# 4792                                            ['日本語']
#
#                                            title  \
# 0                                         Avatar
# 3                          The Dark Knight Rises
# 6                                        Tangled
# 7                        Avengers: Age of Ultron
# 8         Harry Potter and the Half-Blood Prince
# 12    Pirates of the Caribbean: Dead Man's Chest
# 16                                  The Avengers
# 19     The Hobbit: The Battle of the Five Armies
# 22           The Hobbit: The Desolation of Smaug
# 25                                       Titanic
# 26                    Captain America: Civil War
# 34                           Monsters University
# 42                                   Toy Story 3
# 44                                     Furious 7
# 46                    X-Men: Days of Future Past
# 47                       Star Trek Into Darkness
# 49                              The Great Gatsby
# 57                                        WALL·E
# 65                               The Dark Knight
# 66                                            Up
# 68                                      Iron Man
# 69                                          Hugo
# 74                              Edge of Tomorrow
# 77                                    Inside Out
# 81                                    Maleficent
# 82                Dawn of the Planet of the Apes
# 85           Captain America: The Winter Soldier
# 88                                    Big Hero 6
# 89                                Wreck-It Ralph
# 92                      How to Train Your Dragon
# ...                                          ...
# 4456                       Raising Victor Vargas
# 4461                               The Mudge Boy
# 4479                                   High Noon
# 4480                                 Hoop Dreams
# 4495                                     Top Hat
# 4497                                   Woodstock
# 4507                          A Hard Day's Night
# 4511                                   Fireproof
# 4518                           The Station Agent
# 4521                              Beyond the Mat
# 4524   Sholem Aleichem: Laughing In The Darkness
# 4535                               Seven Samurai
# 4579             Monty Python and the Holy Grail
# 4582                                   Tarnation
# 4592                                 Intolerance
# 4595                               The Evil Dead
# 4602                                12 Angry Men
# 4604                       It Happened One Night
# 4606                         Tupac: Resurrection
# 4641                 I Married a Strange Person!
# 4661                              The Big Parade
# 4672                        A Fistful of Dollars
# 4695                          Children of Heaven
# 4696                                     Weekend
# 4704                                        Once
# 4713                                  Roger & Me
# 4724                                  Eraserhead
# 4738                                          Pi
# 4773                                      Clerks
# 4792                                        Cure
#
#                                                    cast  vote_average  \
# 0     ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...           7.2
# 3     ['Christian Bale', 'Michael Caine', 'Gary Oldm...           7.6
# 6     ['Zachary Levi', 'Mandy Moore', 'Donna Murphy'...           7.4
# 7     ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark...           7.3
# 8     ['Daniel Radcliffe', 'Rupert Grint', 'Emma Wat...           7.4
# 12    ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...           7.0
# 16    ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruf...           7.4
# 19    ['Martin Freeman', 'Ian McKellen', 'Richard Ar...           7.1
# 22    ['Martin Freeman', 'Ian McKellen', 'Richard Ar...           7.6
# 25    ['Kate Winslet', 'Leonardo DiCaprio', 'Frances...           7.5
# 26    ['Chris Evans', 'Robert Downey Jr.', 'Scarlett...           7.1
# 34    ['Billy Crystal', 'John Goodman', 'Steve Busce...           7.0
# 42    ['Tom Hanks', 'Tim Allen', 'Ned Beatty', 'Joan...           7.6
# 44    ['Vin Diesel', 'Paul Walker', 'Dwayne Johnson'...           7.3
# 46    ['Hugh Jackman', 'James McAvoy', 'Michael Fass...           7.5
# 47    ['Chris Pine', 'Zachary Quinto', 'Zoe Saldana'...           7.4
# 49    ['Leonardo DiCaprio', 'Tobey Maguire', 'Carey ...           7.3
# 57    ['Ben Burtt', 'Elissa Knight', 'Jeff Garlin', ...           7.8
# 65    ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...           8.2
# 66    ['Ed Asner', 'Christopher Plummer', 'Jordan Na...           7.7
# 68    ['Robert Downey Jr.', 'Terrence Howard', 'Jeff...           7.4
# 69    ['Ben Kingsley', 'Sacha Baron Cohen', 'Asa But...           7.0
# 74    ['Tom Cruise', 'Emily Blunt', 'Brendan Gleeson...           7.6
# 77    ['Amy Poehler', 'Phyllis Smith', 'Richard Kind...           8.0
# 81    ['Angelina Jolie', 'Elle Fanning', 'Sharlto Co...           7.0
# 82    ['Andy Serkis', 'Jason Clarke', 'Gary Oldman',...           7.3
# 85    ['Chris Evans', 'Samuel L. Jackson', 'Scarlett...           7.6
# 88    ['Scott Adsit', 'Ryan Potter', 'Daniel Henney'...           7.8
# 89    ['John C. Reilly', 'Sarah Silverman', 'Jack Mc...           7.1
# 92    ['Jay Baruchel', 'Gerard Butler', 'Craig Fergu...           7.5
# ...                                                 ...           ...
# 4456  ['Victor Rasuk', 'Judy Marte', 'Melonie Diaz',...           7.8
# 4461  ['Emile Hirsch', 'Tom Guiry', 'Richard Jenkins...           7.3
# 4479  ['Gary Cooper', 'Grace Kelly', 'Thomas Mitchel...           7.6
# 4480    ['William Gates', 'Arthur Agee', 'Steve James']           7.7
# 4495  ['Fred Astaire', 'Ginger Rogers', 'Edward Ever...           7.4
# 4497  ['Joe Cocker', 'Richie Havens', 'Joan Baez', '...           7.1
# 4507  ['John Lennon', 'Paul McCartney', 'George Harr...           7.3
# 4511  ['Kirk Cameron', 'Erin Bethea', 'Ken Bevel', '...           7.0
# 4518  ['Peter Dinklage', 'Patricia Clarkson', 'Bobby...           7.4
# 4521  ['Mick Foley', 'Terry Funk', 'Vince McMahon', ...           7.8
# 4524  ['Rachel Dratch', 'Hillel Halkin', 'Jason Krav...           7.0
# 4535  ['Toshirō Mifune', 'Takashi Shimura', 'Yoshio ...           8.2
# 4579  ['Graham Chapman', 'John Cleese', 'Terry Gilli...           7.8
# 4582  ['Renee Leblanc', 'Adolph Davis', 'Jonathan Ca...           7.5
# 4592  ['Lillian Gish', 'Mae Marsh', 'Robert Harron',...           7.4
# 4595  ['Bruce Campbell', 'Ellen Sandweiss', 'Richard...           7.3
# 4602  ['Henry Fonda', 'Martin Balsam', 'John Fiedler...           8.2
# 4604  ['Clark Gable', 'Claudette Colbert', 'Walter C...           7.7
# 4606                             ['Tupac Amaru Shakur']           8.0
# 4641  ['Charis Michelsen', 'Tom Larson', 'Richard Sp...           7.5
# 4661  ['John Gilbert', 'Renée Adorée', 'Hobart Boswo...           7.0
# 4672  ['Clint Eastwood', 'Marianne Koch', 'Gian Mari...           7.6
# 4695  ['Mohammad Amir Naji', 'Amir Farrokh Hashemian...           7.8
# 4696  ['Tom Cullen', 'Chris New', 'Jonathan Race', '...           7.4
# 4704  ['Glen Hansard', 'Markéta Irglová', 'Hugh Wals...           7.3
# 4713  ['Michael Moore', 'Roger B. Smith', 'Rhonda Br...           7.4
# 4724  ['Jack Nance', 'Charlotte Stewart', 'Allen Jos...           7.5
# 4738  ['Sean Gullette', 'Mark Margolis', 'Ben Shenkm...           7.1
# 4773  ["Brian O'Halloran", 'Jeff Anderson', 'Jason M...           7.4
# 4792  ['Koji Yakusho', 'Masato Hagiwara', 'Tsuyoshi ...           7.4
#
#       vote_count
# 0          11800
# 3           9106
# 6           3330
# 7           6767
# 8           5293
# 12          5246
# 16         11776
# 19          4760
# 22          4524
# 25          7562
# 26          7241
# 34          3528
# 42          4597
# 44          4176
# 46          6032
# 47          4418
# 49          3769
# 57          6296
# 65         12002
# 66          6870
# 68          8776
# 69          2141
# 74          4858
# 77          6560
# 81          4496
# 82          4410
# 85          5764
# 88          6135
# 89          4570
# 92          4227
# ...          ...
# 4456          13
# 4461          23
# 4479         334
# 4480          87
# 4495          59
# 4497          66
# 4507         168
# 4511         100
# 4518         210
# 4521          17
# 4524           2
# 4535         878
# 4579        1708
# 4582          22
# 4592          60
# 4595         894
# 4602        2078
# 4604         275
# 4606          26
# 4641          12
# 4661          21
# 4672         883
# 4695         112
# 4696         163
# 4704         453
# 4713          90
# 4724         485
# 4738         586
# 4773         755
# 4792          63
#
# [768 rows x 15 columns]

# %%
# ans to Q5
# Year we had the most number of profitable movies.
# we'll first have to define a profitable movies

#plotting a histogram of runtime of movies

#giving the figure size(width, height)
plt.figure(figsize=(9,5), dpi = 100)

#On x-axis 
plt.xlabel('Runtime of the Movies', fontsize = 15)
#On y-axis 
plt.ylabel('Nos.of Movies in the Dataset', fontsize=15)
#Name of the graph
plt.title('Runtime of all the movies', fontsize=15)

#giving a histogram plot
plt.hist(movies_df['runtime'], rwidth = 0.9, bins =35)
#displays the plot
plt.show()

# %%
profits_year = movies_df.groupby('release_year')['profit'].sum()

#figure size(width, height)
plt.figure(figsize=(12,6), dpi = 130)

#on x-axis
plt.xlabel('Release Year of Movies in the data set', fontsize = 12)
#on y-axis
plt.ylabel('Profits earned by Movies', fontsize = 12)
#title of the line plot
plt.title('Representing Total Profits earned by all movies Vs Year of their release.')

#plotting the graph
plt.plot(profits_year)

#displaying the line plot
plt.show()

# %%
# Most profitable year from the given dataset.
profits_year.idxmax()
# Out:
# 2014

# %%
#selecting the movies having profit $50M or more
profit_data = movies_df[movies_df['profit'] >= 50000000]

#reindexing new data
profit_data.index = range(len(profit_data))

#we will start from 1 instead of 0
profit_data.index = profit_data.index + 1

#printing the changed dataset
profit_data.head(10)
# Out:
#        budget      profit     revenue  \
# 1   237000000  2550965087  2787965087
# 2   300000000   661000000   961000000
# 3   245000000   635674609   880674609
# 4   250000000   834939099  1084939099
# 5   258000000   632871626   890871626
# 6   260000000   331794936   591794936
# 7   280000000  1125403694  1405403694
# 8   250000000   683959197   933959197
# 9   250000000   623260194   873260194
# 10  270000000   121081192   391081192
#
#                                                genres      id  popularity  \
# 1   ['Action', 'Adventure', 'Fantasy', 'Science Fi...   19995  150.437577
# 2                  ['Adventure', 'Fantasy', 'Action']     285  139.082615
# 3                    ['Action', 'Adventure', 'Crime']  206647  107.376788
# 4            ['Action', 'Crime', 'Drama', 'Thriller']   49026  112.312950
# 5                  ['Fantasy', 'Action', 'Adventure']     559  115.699814
# 6                             ['Animation', 'Family']   38757   48.681969
# 7          ['Action', 'Adventure', 'Science Fiction']   99861  134.279229
# 8                  ['Adventure', 'Fantasy', 'Family']     767   98.885637
# 9                  ['Action', 'Adventure', 'Fantasy']  209112  155.790452
# 10  ['Adventure', 'Fantasy', 'Action', 'Science Fi...    1452   57.925623
#
#                               production_countries release_date  release_year  \
# 1   ['United States of America', 'United Kingdom']   2009-12-10          2009
# 2                     ['United States of America']   2007-05-19          2007
# 3   ['United Kingdom', 'United States of America']   2015-10-26          2015
# 4                     ['United States of America']   2012-07-16          2012
# 5                     ['United States of America']   2007-05-01          2007
# 6                     ['United States of America']   2010-11-24          2010
# 7                     ['United States of America']   2015-04-22          2015
# 8   ['United Kingdom', 'United States of America']   2009-07-07          2009
# 9                     ['United States of America']   2016-03-23          2016
# 10                    ['United States of America']   2006-06-28          2006
#
#     runtime                                   spoken_languages  \
# 1     162.0                             ['English', 'Español']
# 2     169.0                                        ['English']
# 3     148.0  ['Français', 'English', 'Español', 'Italiano',...
# 4     165.0                                        ['English']
# 5     139.0                            ['English', 'Français']
# 6     100.0                                        ['English']
# 7     141.0                                        ['English']
# 8     153.0                                        ['English']
# 9     151.0                                        ['English']
# 10    154.0                 ['English', 'Français', 'Deutsch']
#
#                                        title  \
# 1                                     Avatar
# 2   Pirates of the Caribbean: At World's End
# 3                                    Spectre
# 4                      The Dark Knight Rises
# 5                               Spider-Man 3
# 6                                    Tangled
# 7                    Avengers: Age of Ultron
# 8     Harry Potter and the Half-Blood Prince
# 9         Batman v Superman: Dawn of Justice
# 10                          Superman Returns
#
#                                                  cast  vote_average  \
# 1   ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...           7.2
# 2   ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...           6.9
# 3   ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...           6.3
# 4   ['Christian Bale', 'Michael Caine', 'Gary Oldm...           7.6
# 5   ['Tobey Maguire', 'Kirsten Dunst', 'James Fran...           5.9
# 6   ['Zachary Levi', 'Mandy Moore', 'Donna Murphy'...           7.4
# 7   ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark...           7.3
# 8   ['Daniel Radcliffe', 'Rupert Grint', 'Emma Wat...           7.4
# 9   ['Ben Affleck', 'Henry Cavill', 'Gal Gadot', '...           5.7
# 10  ['Brandon Routh', 'Kevin Spacey', 'Kate Boswor...           5.4
#
#     vote_count
# 1        11800
# 2         4500
# 3         4466
# 4         9106
# 5         3576
# 6         3330
# 7         6767
# 8         5293
# 9         7004
# 10        1400

# %%
# ans to secondary Q1
# formatting the data in the genres columns.
profit_data['genres']=profit_data['genres'].str.strip('[]').str.replace(' ','').str.replace("'",'')

profit_data['genres']=profit_data['genres'].str.split(',')

profit_data.head()
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#       budget      profit     revenue  \
# 1  237000000  2550965087  2787965087
# 2  300000000   661000000   961000000
# 3  245000000   635674609   880674609
# 4  250000000   834939099  1084939099
# 5  258000000   632871626   890871626
#
#                                          genres      id  popularity  \
# 1  [Action, Adventure, Fantasy, ScienceFiction]   19995  150.437577
# 2                  [Adventure, Fantasy, Action]     285  139.082615
# 3                    [Action, Adventure, Crime]  206647  107.376788
# 4              [Action, Crime, Drama, Thriller]   49026  112.312950
# 5                  [Fantasy, Action, Adventure]     559  115.699814
#
#                              production_countries release_date  release_year  \
# 1  ['United States of America', 'United Kingdom']   2009-12-10          2009
# 2                    ['United States of America']   2007-05-19          2007
# 3  ['United Kingdom', 'United States of America']   2015-10-26          2015
# 4                    ['United States of America']   2012-07-16          2012
# 5                    ['United States of America']   2007-05-01          2007
#
#    runtime                                   spoken_languages  \
# 1    162.0                             ['English', 'Español']
# 2    169.0                                        ['English']
# 3    148.0  ['Français', 'English', 'Español', 'Italiano',...
# 4    165.0                                        ['English']
# 5    139.0                            ['English', 'Français']
#
#                                       title  \
# 1                                    Avatar
# 2  Pirates of the Caribbean: At World's End
# 3                                   Spectre
# 4                     The Dark Knight Rises
# 5                              Spider-Man 3
#
#                                                 cast  vote_average  vote_count
# 1  ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...           7.2       11800
# 2  ['Johnny Depp', 'Orlando Bloom', 'Keira Knight...           6.9        4500
# 3  ['Daniel Craig', 'Christoph Waltz', 'Léa Seydo...           6.3        4466
# 4  ['Christian Bale', 'Michael Caine', 'Gary Oldm...           7.6        9106
# 5  ['Tobey Maguire', 'Kirsten Dunst', 'James Fran...           5.9        3576

# %%
# plt.subplots(figsize=(12,10))
list1=[]

# extending the list of genres to collect all the genres of all the profitable movies
for i in profit_data['genres']:
    list1.extend(i)
ax = pd.Series(list1).value_counts()[:10].sort_values(ascending=True).plot.barh(
    width=0.9,
    color=sns.color_palette('summer_r',10))
ax

# %%
plt.subplots(figsize=(12,10))
list1=[]

# extending the list of genres to collect all the genres of all the profitable movies
for i in profit_data['genres']:
    list1.extend(i)
    
ax = pd.Series(list1).value_counts()[:10].sort_values(ascending=True).plot.barh(
    width=0.9,
    color=sns.color_palette('summer_r',10))

for i, v in enumerate(pd.Series(list1).value_counts()[:10].sort_values(ascending=True).values): 
    ax.text(.8, i, v,fontsize=12,color='white',weight='bold')
ax.patches[9].set_facecolor('r')
plt.title('Top Genres')
plt.show()

# %%
"""Most frequent cast
Let's try to find out the most frequent cast in the movies based on which we can tell about the success factor of the cast."""
profit_data['cast']=profit_data['cast'].str.strip('[]').str.replace(' ','').str.replace("'",'')
profit_data['cast']=profit_data['cast'].str.split(',')

plt.subplots(figsize=(12,10))
list1=[]
for i in profit_data['cast']:
    list1.extend(i)
ax = pd.Series(list1).value_counts()[:10].sort_values(ascending=True).plot.barh(width=0.9,color=sns.color_palette('summer_r',10))
for i, v in enumerate(pd.Series(list1).value_counts()[:10].sort_values(ascending=True).values): 
    ax.text(.8, i, v,fontsize=12,color='white',weight='bold')
ax.patches[9].set_facecolor('r')
plt.title('Top Cast')
plt.show()
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# ans to Q3
profit_data['profit'].mean()
profit_data['revenue'].mean()
# Out:
# 262022090.17768925

# %%
# ans to Q4
profit_data['runtime'].mean()
# Out:
# 114.37928286852589

# %%
# ans to Q5
profit_data['budget'].mean()
# Out:
# 63032056.92111554

# %%
# ans to Q6
profit_data['spoken_languages']=profit_data['spoken_languages'].str.strip('[]').str.replace(' ','').str.replace("'",'')
profit_data['spoken_languages']=profit_data['spoken_languages'].str.split(',')

plt.subplots(figsize=(12,10))
list1=[]
for i in profit_data['spoken_languages']:
    list1.extend(i)
ax = pd.Series(list1).value_counts()[:10].sort_values(ascending=True).plot.barh(width=0.9,color=sns.color_palette('summer_r',10))
for i, v in enumerate(pd.Series(list1).value_counts()[:10].sort_values(ascending=True).values): 
    ax.text(.8, i, v,fontsize=12,color='white',weight='bold')
ax.patches[9].set_facecolor('r')
plt.title('Frequency of language used!')
plt.show()
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# <h2> CONCLUSION </h2>
# This was a very interesting data analysis. We came out with some very interesting facts about movies.
# After this analysis we can conclude following:
#
# For a Movie to be in successful criteria
# <ul>
#     <li><u>Average Budget</u> must be around <u>63 millon dollar</u></li>
#     <li><u>Average duration</u> of the movie must be <u>114 minutes</u> </li>
#     <li>Any one of these should be in the <u>cast</u> : Samuel Jackson, Robert De Neiro, Morgan Freeman, Bruce Willis </li>
#     <li><u>Genre</u> must be : Action, Adventure, Thriller, Comedy, Drama. </li>
# </ul>
# By doing all this the movie might be one of the hits and hence can earn an average revenue of around 262 million dollar.
